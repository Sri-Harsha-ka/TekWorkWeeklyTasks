# %%
# Deep Learing 

# This automatically learns features from raw data. 
# ex : it is comparable to how children learn 

# ML 
# Raw data -- features -- model -- decision

# DL 
# Raw Data -- Neural network -- features -- decision 

# Human Brain is equal to Neural Network in Context

# When to using Deep Learning :

# if data is ustructred 
# Patterns are complex
#     -- Face recogz
#     -- Voice assistance 
#     -- Self driving cars 
#     -- ChatBots

# If data looks like in exvel or table format -- use ML 
# If data looks like real life format -- use DL

# %% [markdown]
# ## Biological Neurans
#
#
# ![neuron-structure-concept-description-anatomy-260nw-2507272247.webp](attachment:fa8b28c8-d657-4da8-9ef4-77cda3d917a9.webp)
#
# ## Artifical Neurans
#
# ![image.png](attachment:fb93c0b8-8e73-4d5b-b6b0-a4977f114dec.png)
#
#
# ## Parts of Neuron:
#
# 1. Recevives Signals ( Data )
# 2. Process the data
# 3. Decides weather to pass the signal or not
#
# **Why Deep Learning ?**
#
# We use Deep Learning to Predict complex data using Neural Networks
# when we are unavable to find the features
# when data is not in a structured format
#
# **What is a Neuron ?**
#
# It is a Fundamental Processing unit of a Neural network
# Its used to take the input , process and make a decision of sending the ouput or not
#
#
# **Why computer needs a neron model ?**
#
# 1. Efficient way to process the raw data
# 2. Taking a reference of human nerouns to achive similar procesing and results
#
#
# ## Artifical Neurans and Biological Neurans
#
#
# ![image.png](attachment:11a96fb3-0fc7-4ac3-9fde-4bb94d6919f7.png)
#
#
# ### Artificial Neuron Parts
#
#
# - Input Signal
# - Weights
# - Sum of Inputs
# - Add Bias
# - Activation function
#
# **Why is Activation function is required ?**
#
# It takes the summation function and converts it into desired output
#
# **Perceptron**
#
# Perceptron is a single neuron model.
# it can only solve the classification problems only ( binary classification )
#
#
# ### Code Examples and syntax
#
# ```python
# model = Sequential()
# model.add(Dense(1,input_dim=2 , activation= 'sigmoid'))
# ```
# 1 : Number of Neurons
#
# input_dim : Number of inputs
#
# sigmoid : binary ouput ( activation function )
#
# ```python
# model.compile(optimizer='adam' , loss = 'binary_crossentropy' , metrics = ['accuracy'])
# ```
# optimizer : how weights are updated
#
# loss : how error is calculated
#
# metrics : how performace is measured
#
# Limitation of Perceptron :
# 1. Works only for binary classification
# 2. Does not work for XOR because of
#
# ![image.png](attachment:51424b44-078c-4c39-a368-497134f0a7af.png)
#
#
# **These are 3 activation functions :**
#
# 1. Sigmoid :
# 2. ReLu ( Rectified Linear unit ) :
# 3. SoftMax :
#
# Sigmoid :
#
#           0.5 < 0
#           0.5 > 1
#
# ex : spam or not , pase or fail
#
# ReLu :
#
#        0<    value
#        0>    0
#
# ex :
#
# Softmax : when we have multi classes then use softmax activation
#
# #### Loss Function
#
# Froward Propagation
# Backward Propagation
