# %%
def deposite():
    acbal=10000
    amt=int(input("Enter your deposite amount:  "))
    if amt%100==0 and amt<50000:
        acbal=acbal+amt
    else:
        print("Please enter multiples of 100 only or transiton should be less than 50,000")
    
    print("Avalaible bal :",acbal)

def withdraw():
    

    
def viewOptions():
    print("1. deposite")
    print("2. withdraw")
    print("3. bal Enquiry")
    print("0. EXIT")
    option=int(input("Choose your option: "))
    if option==1:
        deposite()
    elif option==2:
        print("Withdraw")
    elif option==3:
        print("Bal Enquiry")
    elif option==0:
        print("Thank you, visit again")
    else:
        print("Invalid option")

        

viewOptions()
# Out:
# 1. deposite
# 2. withdraw
# 3. bal Enquiry
# 0. EXIT
# Choose your option:  1
# Enter your deposite amount:   50001
# Please enter multiples of 100 only or transiton should be less than 50,000
# Avalaible bal : 10000

# %%
class userSystem: 

    users = []

    def getStarted(self):
        print("--------------------------")
        print("Select an Option")
        print("1.Create a User Account")
        print("2.Login a Account")
        print("3.Exit")
        option = int(input("Enter the Option"))
        if option == 1:
            self.create()
        elif option == 2:
            self.login()
        elif option == 3:
            return 1
        else:
            print("Invalid")
        return 0

    def getusers(self):
        print(self.users)

    def create(self):
        print("--------------------------")
        print("Welcome to Our GOATED Bank")
        name = input("Enter your Name, with size greater than 2")
        if len(name)<=2:
            print("Please enter a proper name")
        self.users.append(name)
        self.getusers()

    def login(self):
        print("--------------------------")
        print("Welcome Back to Our GOATED Bank")
        name = input("Enter your Name")
        if len(self.users) == 0:
            print("Bad Guy , Login you account niga")
        for ele in self.users:
            if ele == name:
                print(f"Welcome , {name}")
                bankObj = BankOperations()
                while(1):
                    exit = bankObj.getOption()
                    if exit:
                        break
            else:
                print("Bad Guy , Login you account niga")
        
            
        

class BankOperations: 

    actbal = 1000

    def deposite(self):
        self.actbal+=100

    def withdraw(self):
        pass

    def checkBalance(self):
        print(self.actbal)
    
    def getOption(self):
        print("--------------------------")
        print("Operations you can perform")
        print("1. Deposite")
        print("2. Withdraw")
        print("3.Check Balance")
        print("4. Balance Enquiry")
        print("5. EXIT")
        option=int(input("Choose your option: "))
        if option==1:
            self.deposite()
        elif option==2:
            print("Withdraw")
        elif option==3:
            self.checkBalance()
        elif option==0:
            print("Thank you, visit again")
        elif option == 5:
            return 1
        else:
            print("Invalid option")
        return 0

while(1):
    userObj = userSystem()
    exit = userObj.getStarted()
    if(exit):
        break
# Out:
# --------------------------
# Select an Option
# 1.Create a User Account
# 2.Login a Account
# 3.Exit

# %%
class a:
    val = 10
    def getval(self):
        return self.val

class b:
    for i in range(2):
        obj = a()
        if i == 1:
            a.val +=10
        print(a.val)
# Out:
# 10
# 20
