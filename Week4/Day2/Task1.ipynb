# %%
text = "hi my id sumit@gmail.com and nagil@teckwork.com"


lis = text.split(' ')

lis

res = []

for i in lis:
    for ch in i:
        if ch == "@" or ch == ".":
            res.append(i)

# %%
res
# Out:
# ['sumit@gmail.com',
#  'sumit@gmail.com',
#  'nagil@teckwork.com',
#  'nagil@teckwork.com']

# %%
import re 
ans = re.findall(r'\w+@+\w+.+\w', text)
ans
# Out:
# ['sumit@gmail.com and nagil@teckwork.com']
