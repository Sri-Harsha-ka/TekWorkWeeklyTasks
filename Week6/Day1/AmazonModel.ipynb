# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('amazon_laptop_price_dataset.csv')
df.head()
# Out:
#     Brand    Processor  RAM_GB  Storage_GB Operating_System              GPU  \
# 0     MSI  AMD Ryzen 3       4         512            macOS       AMD Radeon
# 1  Lenovo     Intel i7      32         128            macOS  NVIDIA GTX 1650
# 2    Asus  AMD Ryzen 7       8         256       Windows 10       Integrated
# 3    Dell     Intel i7      16         512       Windows 11       AMD Radeon
# 4     MSI  AMD Ryzen 7       8         512       Windows 11  NVIDIA RTX 3050
#
#    Rating  Price_USD
# 0     4.2    1092.04
# 1     3.1    1934.84
# 2     3.6     758.86
# 3     3.6    1430.88
# 4     3.8    1457.77

# %%
# Tasks 1 : Check for outlires for Price
# Task 2 : Convert Price to INR 

df.Price_USD.describe()
# Out:
# count    1000.000000
# mean     1462.197300
# std       479.697515
# min       404.830000
# 25%      1101.552500
# 50%      1421.705000
# 75%      1793.382500
# max      2896.850000
# Name: Price_USD, dtype: float64

# %%
df['Price_INR'] = df['Price_USD']*90.92
df.drop('Price_USD', axis = 1 , inplace=True)

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
q1 = df['Price_INR'].quantile(0.25)
q3 = df['Price_INR'].quantile(0.75)
iqr = q3-q1
lob = q1 - 1.5*iqr
upb = q3 + 1.5*iqr 
df_outliers = df[
    (df['Price_INR'] >= lob) |
    (df['Price_INR'] <= upb)
]

# %%
df_outliers
# Out:
#       Brand    Processor  RAM_GB  Storage_GB Operating_System  \
# 0       MSI  AMD Ryzen 3       4         512            macOS
# 1    Lenovo     Intel i7      32         128            macOS
# 2      Asus  AMD Ryzen 7       8         256       Windows 10
# 3      Dell     Intel i7      16         512       Windows 11
# 4       MSI  AMD Ryzen 7       8         512       Windows 11
# ..      ...          ...     ...         ...              ...
# 995    Dell     Intel i5       8        1024       Windows 10
# 996   Apple  AMD Ryzen 5       8         256       Windows 10
# 997   Apple  AMD Ryzen 5      32         512       Windows 10
# 998    Dell  AMD Ryzen 5      32         128       Windows 11
# 999   Apple  AMD Ryzen 3       4         256       Windows 10
#
#                  GPU  Rating    Price_INR
# 0         AMD Radeon     4.2   99288.2768
# 1    NVIDIA GTX 1650     3.1  175915.6528
# 2         Integrated     3.6   68995.5512
# 3         AMD Radeon     3.6  130095.6096
# ...

# %%
df.nunique()
# Out:
# Brand                 7
# Processor             6
# RAM_GB                4
# Storage_GB            4
# Operating_System      3
# GPU                   4
# Rating               21
# Price_INR           993
# dtype: int64

# %%
col_names = ['Brand' , 'Processor' , 'RAM_GB' , 'Operating_System' , 'GPU', 'Rating']

for col in col_names :
    print(col)
    print(df[col].unique())
    print()
# Out:
# Brand
# ['MSI' 'Lenovo' 'Asus' 'Dell' 'Acer' 'Apple' 'HP']
#
# Processor
# ['AMD Ryzen 3' 'Intel i7' 'AMD Ryzen 7' 'Intel i5' 'Intel i3'
#  'AMD Ryzen 5']
#
# RAM_GB
# [ 4 32  8 16]
#
# Operating_System
# ['macOS' 'Windows 10' 'Windows 11']
#
# GPU
# ['AMD Radeon' 'NVIDIA GTX 1650' 'Integrated' 'NVIDIA RTX 3050']
#
# Rating
# [4.2 3.1 3.6 3.8 3.  4.8 4.  3.7 4.3 3.9 3.5 4.1 3.2 3.3 4.4 4.7 4.9 4.6
#  4.5 5.  3.4]

# %%
df['Operating_System'] = df['Operating_System'].replace({
    'Windows 10': 'Windows',
    'Windows 11': 'Windows'
})

# %%
df.head()
# Out:
#     Brand    Processor  RAM_GB  Storage_GB Operating_System              GPU  \
# 0     MSI  AMD Ryzen 3       4         512            macOS       AMD Radeon
# 1  Lenovo     Intel i7      32         128            macOS  NVIDIA GTX 1650
# 2    Asus  AMD Ryzen 7       8         256          Windows       Integrated
# 3    Dell     Intel i7      16         512          Windows       AMD Radeon
# 4     MSI  AMD Ryzen 7       8         512          Windows  NVIDIA RTX 3050
#
#    Rating    Price_INR
# 0     4.2   99288.2768
# 1     3.1  175915.6528
# 2     3.6   68995.5512
# 3     3.6  130095.6096
# 4     3.8  132540.4484

# %%
df.GPU.replace({'AMD Radeon': 0 , 'NVIDIA GTX 1650' : 1, 'NVIDIA RTX 3050' : 2, 'Integrated':3} , inplace=True)
df.GPU.value_counts()
# Out:
# C:\Users\SriHarshaK\AppData\Local\Temp\ipykernel_119196\479193449.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.GPU.replace({'AMD Radeon': 0 , 'NVIDIA GTX 1650' : 1, 'NVIDIA RTX 3050' : 2, 'Integrated':3} , inplace=True)
# GPU
# 3    279
# 0    268
# 2    246
# 1    207
# Name: count, dtype: int64

# %%
# task 1: brand col convert into number using one hot encoding
 
# task 2 : brand_encoded add in the dataframe
 
# task 3 : all brand col convert into int
 
# task 4: divide data into x and y
 
# task 5 : split data into train and test
 
# task 6: train model , load model , fit model , predict
 
# task 7: find the mse , mae
 
# task 8: find the r2 

df.head()
# Out:
#     Brand    Processor  RAM_GB  Storage_GB Operating_System  GPU  Rating  \
# 0     MSI  AMD Ryzen 3       4         512            macOS    0     4.2
# 1  Lenovo     Intel i7      32         128            macOS    1     3.1
# 2    Asus  AMD Ryzen 7       8         256          Windows    3     3.6
# 3    Dell     Intel i7      16         512          Windows    0     3.6
# 4     MSI  AMD Ryzen 7       8         512          Windows    2     3.8
#
#      Price_INR
# 0   99288.2768
# 1  175915.6528
# 2   68995.5512
# 3  130095.6096
# 4  132540.4484

# %%
df.Brand.unique()
# Out:
# array(['MSI', 'Lenovo', 'Asus', 'Dell', 'Acer', 'Apple', 'HP'],
#       dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
ohe = OneHotEncoder()
encoded=ohe.fit_transform([df['Brand']])
encoded
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 1000 stored elements and shape (1, 1000)>

# %%
df.head()
# Out:
#     Brand    Processor  RAM_GB  Storage_GB Operating_System  GPU  Rating  \
# 0     MSI  AMD Ryzen 3       4         512            macOS    0     4.2
# 1  Lenovo     Intel i7      32         128            macOS    1     3.1
# 2    Asus  AMD Ryzen 7       8         256          Windows    3     3.6
# 3    Dell     Intel i7      16         512          Windows    0     3.6
# 4     MSI  AMD Ryzen 7       8         512          Windows    2     3.8
#
#      Price_INR
# 0   99288.2768
# 1  175915.6528
# 2   68995.5512
# 3  130095.6096
# 4  132540.4484
