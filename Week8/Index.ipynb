# %%
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("./data/overfitting_dataset.csv")
df.head()
# Out:
#    feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0   0.496714  -0.138264   0.647689   1.523030  -0.234153   0.491200
# 1   1.465649  -0.225776   0.067528  -1.424748  -0.544383   1.120915
# 2   0.738467   0.171368  -0.115648  -0.301104  -1.478522   0.600385
# 3  -0.479174  -0.185659  -1.106335  -1.196207   0.812526  -0.429567
# 4  -0.219672   0.357113   1.477894  -0.518270  -0.808494  -0.219187
#
#    feature_6  feature_7  feature_8  feature_9  ...  feature_11  feature_12  \
# 0  -0.101731   0.767435  -0.469474   0.542560  ...   -0.465730    0.241962
# 1  -0.090561   0.375698  -0.600639  -0.291694  ...    1.852278   -0.013497
# 2   0.007686   1.057122   0.343618  -1.763040  ...   -0.385082   -0.676922
# 3  -0.091720   1.003533   0.361636  -0.645120  ...    1.538037   -0.035826
# 4   0.266624   0.328751  -0.529760   0.513267  ...    0.968645   -0.702053
#
#    feature_13  feature_14  feature_15  feature_16  feature_17  feature_18  \
# ...

# %%
df.describe()
# Out:
#        feature_0  feature_1  feature_2  feature_3  feature_4  feature_5  \
# count  40.000000  40.000000  40.000000  40.000000  40.000000  40.000000
# mean    0.029524  -0.003657  -0.084381   0.068184  -0.184437   0.033525
# std     0.989348   0.999557   1.206141   1.017490   0.947201   0.797209
# min    -1.840874  -1.867265  -3.241267  -1.612716  -2.471645  -1.572535
# 25%    -0.790986  -0.663834  -0.732813  -0.608138  -0.760164  -0.543089
# 50%     0.145609  -0.087131  -0.070757   0.115807  -0.239948   0.127428
# 75%     0.649669   0.569378   0.701519   0.643755   0.528192   0.502685
# max     2.314659   2.075401   2.560085   2.270693   2.133033   1.807754
#
#        feature_6  feature_7  feature_8  feature_9  ...  feature_11  \
# count  40.000000  40.000000  40.000000  40.000000  ...   40.000000
# mean    0.012279   0.048772  -0.114112  -0.048619  ...    0.053765
# std     0.703429   0.961052   0.920906   1.128897  ...    1.129215
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 21 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   feature_0   40 non-null     float64
#  1   feature_1   40 non-null     float64
#  2   feature_2   40 non-null     float64
#  3   feature_3   40 non-null     float64
#  4   feature_4   40 non-null     float64
#  5   feature_5   40 non-null     float64
#  6   feature_6   40 non-null     float64
#  7   feature_7   40 non-null     float64
#  8   feature_8   40 non-null     float64
#  9   feature_9   40 non-null     float64
#  10  feature_10  40 non-null     float64
#  11  feature_11  40 non-null     float64
#  12  feature_12  40 non-null     float64
#  13  feature_13  40 non-null     float64
#  14  feature_14  40 non-null     float64
#  15  feature_15  40 non-null     float64
#  16  feature_16  40 non-null     float64
#  17  feature_17  40 non-null     float64
# ...

# %%
sns.boxplot(df )
plt.xticks(rotation=90)
plt.show()

# %%
X = df.iloc[: , : -1]
y = df.iloc[: , -1]

# %%
X.shape , y.shape
# Out:
# ((40, 20), (40,))

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X, y , test_size = 0.2)

# %%
X_train.shape , X_test.shape
# Out:
# ((32, 20), (8, 20))

# %%
from sklearn.linear_model import LinearRegression
lr = LinearRegression()
lr.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
y_preds = lr.predict(X_test)

# %%
from sklearn.metrics import r2_score , mean_squared_error

# %%
r2_score(y_test , y_preds)
# Out:
# 0.8988219445954231

# %%
mean_squared_error(y_test , y_preds)
# Out:
# 5.971007080059925

# %%
from sklearn.linear_model import Ridge
ridge_model = Ridge(alpha = 1.0)
ridge_model.fit(X_train , y_train )
# Out:
# Ridge()

# %%
rg_preds = ridge_model.predict(X_test)

# %%
print ( " testing " , r2_score(rg_preds , y_test)) 
print( " train " , r2_score(rg_preds_train , y_train) )
# Out:
#  testing  0.9888266351403247
#  train  0.937902054123918

# %%
rg_preds_train  = ridge_model.predict(X_trian)

# %%
from sklearn.linear_model import Lasso

# %%
ls = Lasso()
ls.fit(X_train ,y_train)
# Out:
# Lasso()

# %%
ls_preds = ls.predict(X_test)
ls_train_preds = ls.predict(X_train)

# %%
print("testing " , r2_score(ls_preds , y_test))
print("traning " , r2_score(ls_train_preds , y_train))
# Out:
# testing  0.6720925843220831
# traning  0.6433695066009453
