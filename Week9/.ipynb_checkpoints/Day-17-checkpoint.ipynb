# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:\\Clg\\TekWorks\\Datasets\\decision_tree_dataset.csv")
df=pd.DataFrame(data)
df.head()
# Out:
#    age        income  credit_score       city  gender  purchases  \
# 0   41  16832.970365    646.435852  Hyderabad  Female          2
# 1   61  24958.920783    772.103370  Bangalore  Female          2
# 2   29  26661.565307    742.165011  Bangalore    Male          3
# 3   40  76918.367953    789.568381     Mumbai  Female          2
# 4   18  33446.160242    650.679984      Delhi    Male          4
#
#      loan_amount  approved
# 0            NaN         0
# 1  109037.369348         0
# 2  140981.063625         0
# 3  265765.286243         0
# 4  187481.809910         0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050 entries, 0 to 1049
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   age           1050 non-null   int64
#  1   income        947 non-null    float64
#  2   credit_score  946 non-null    float64
#  3   city          1050 non-null   object
#  4   gender        1050 non-null   object
#  5   purchases     1050 non-null   int64
#  6   loan_amount   947 non-null    float64
#  7   approved      1050 non-null   int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 65.8+ KB

# %%
df.describe()
# Out:
#                age         income  credit_score    purchases   loan_amount  \
# count  1050.000000     947.000000    946.000000  1050.000000  9.470000e+02
# mean     43.737143   55807.648029    651.605495     2.934286  2.086066e+05
# std      15.021797   40021.647680    100.166162     1.603281  1.270517e+05
# min      18.000000    6556.169327    348.048784     0.000000 -5.768131e+04
# 25%      31.000000   40886.541936    584.998140     2.000000  1.378232e+05
# 50%      44.000000   50967.116222    650.052796     3.000000  1.971923e+05
# 75%      56.000000   60643.014837    718.563117     4.000000  2.598691e+05
# max      69.000000  445126.233564    969.310757     9.000000  1.233105e+06
#
#           approved
# count  1050.000000
# mean      0.303810
# std       0.460121
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %%
df.isna().sum()
# Out:
# age               0
# income          103
# credit_score    104
# city              0
# gender            0
# purchases         0
# loan_amount     103
# approved          0
# dtype: int64

# %%
import seaborn as sns
sns.boxplot(df)
# Out:
# <Axes: >

# %%
df.shape
# Out:
# (1050, 8)

# %%
# Remove outliers using IQR method - Income
q1 = df['income'].quantile(0.25)
q3 = df['income'].quantile(0.75)

IQR = q3 - q1

lower_bound = q1 - 1.5 * IQR
upper_bound = q3 + 1.5 * IQR

# Count outliers in income
outliers_income = df[(df['income'] < lower_bound) | (df['income'] > upper_bound)]
print(f"Number of outliers in 'income': {len(outliers_income)}")
# Out:
# Number of outliers in 'income': 25

# %%
# Remove outliers using IQR method - Loan Amount
q1 = df['loan_amount'].quantile(0.25)
q3 = df['loan_amount'].quantile(0.75)

IQR = q3 - q1

lower_bound = q1 - 1.5 * IQR
upper_bound = q3 + 1.5 * IQR

# Count outliers in loan_amount
outliers_loan = df[(df['loan_amount'] < lower_bound) | (df['loan_amount'] > upper_bound)]
print(f"Number of outliers in 'loan_amount': {len(outliers_loan)}")
# Out:
# Number of outliers in 'loan_amount': 22

# %%
# Remove all outliers from the dataset
df = df[(df['income'] >= df['income'].quantile(0.25) - 1.5*(df['income'].quantile(0.75) - df['income'].quantile(0.25))) & 
        (df['income'] <= df['income'].quantile(0.75) + 1.5*(df['income'].quantile(0.75) - df['income'].quantile(0.25)))]

df = df[(df['loan_amount'] >= df['loan_amount'].quantile(0.25) - 1.5*(df['loan_amount'].quantile(0.75) - df['loan_amount'].quantile(0.25))) & 
        (df['loan_amount'] <= df['loan_amount'].quantile(0.75) + 1.5*(df['loan_amount'].quantile(0.75) - df['loan_amount'].quantile(0.25)))]

print(f"Dataset shape after removing outliers: {df.shape}")
print(f"Total rows removed: {10000 - len(df)}")  # Assuming original was 10000 rows
