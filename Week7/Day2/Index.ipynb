# %%
import pandas as pd

df = pd.read_csv("data.csv")
df.head()
# Out:
#    Age  InsuranceCost
# 0   22           2500
# 1   25           2800
# 2   28           3200
# 3   30           3500
# 4   35           4200

# %%
X = df[['Age']]
y = df.iloc[:,-1]
X , y
# Out:
# (   Age
#  0   22
#  1   25
#  2   28
#  3   30
#  4   35
#  5   40
#  6   45
#  7   50
#  8   55
#  9   60,
#  0    2500
#  1    2800
#  2    3200
#  3    3500
#  4    4200
#  5    5000
#  6    5800
#  7    6500
#  8    7200
#  9    8000
#  Name: InsuranceCost, dtype: int64)

# %%
import matplotlib.pyplot as plt 
import numpy as np

plt.scatter(X,y)
m ,c = np.polyfit(df['Age'],y, 1) # Here 1 means Stright line
plt.plot(X,m*X+c)

# %%
from sklearn.model_selection import train_test_split
X_train , X_test , y_train , y_test = train_test_split(X , y , test_size = 0.2)
X_train.shape , X_test.shape
# Out:
# ((8, 1), (2, 1))

# %%
from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train , y_train)
# Out:
# LinearRegression()

# %%
lr.coef_ , lr.intercept_
# Out:
# (array([146.86648501]), np.float64(-849.659400544957))

# %%
y_preds = lr.predict(X_test)
