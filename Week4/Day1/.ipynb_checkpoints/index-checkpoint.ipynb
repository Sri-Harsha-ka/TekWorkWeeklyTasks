# %%
# All types of charts 
# 1 . line plot : 
# 2 . bar plot 
# 3. scatter plot 
# 4. box plot 
# 5. histogram 
# 6. pair plot 
# 7. count plot
# 8. heat map 
# 9. cluster map

# %%
# Data Collection 
# 1. Handled missing and types of missing 
# 2. Handled outliers 
# 3. Normalize values 
# 4. Features imp
# 5. Statistocal Analysis

# %% [markdown]
# # Import Libs

# %%
import pandas as pd 
import requests 
from bs4 import BeautifulSoup 
import re

# %% [markdown]
# # The the URL of the web to be scriped

# %%
URL = "https://realpython.github.io/fake-jobs/"

# %%
# Make header to mimic a browser visit

headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}
